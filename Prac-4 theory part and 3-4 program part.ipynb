# %% [markdown]
# Theory Questions

# %% [markdown]
# Q1

# %% [markdown]
# 1.let H(x) x is a people, F(x) is x with black hair symbolization as x(M(x)=F(x)) assume a is girl with blonde hair, then M(a) is true, F(a) is false. so M(a)=>F(a) is false the answer is false.
#
# 2.let G(x) x means one who have boarded the moon. assume someone do have boarded the moon once. therefore M(a)^G(a) is true the propotion is true.
#
# 3.Assume that H(x) means x boarded the jupiter symbolization is -x(M(x)^H(x)) as nobody ever boarded the jupiter so far therefore the statement x(M(x)^H(x)) is false the propositional is true.
#
# 4.Assume F(x) x is a student study in us, G(x) means x is asian then the symbolization is -x(F(x))=G(x) the proposition is true.

# %% [markdown]
# Q2

# %% [markdown]
# 1.Tautology
#
# 2.Contradiction
#
# 3.None of both

# %% [markdown]
# Q3

# %% [markdown]
# 1.False
#
# 2.True
#
# 3.True
#
# 4.True
#
# 5.False

# %% [markdown]
# Q4

# %% [markdown]
# P^(Q=>R)=>S -(P^(-Q∨R))∨S -(PV-(-Q∨R))∨S -(PV-(--Q^-R))∨S -(PV-(Q^-R))∨S -PVSV(Q^-R) (-PVSVQ)^(-PVSV-R)

# %% [markdown]
# Q5

# %% [markdown]
# 1.∀ x Even(x) <=> ∃ y x=y+y
#
# 2.∀x Prime(x)<=> ∀y, zx=y xz =>y=1vz=1
#
# 3.∀x Even(x) =>∃ y,z Prime(y)^Prime(z)^x=y+z

# %% [markdown]
# ###Program Questions

# %% [markdown]
# My MinimaxGhost VS ExpectimaxAgent

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# My MinimaxGhost VS MinimaxAgent

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q3

# %% [markdown]
# In the case of Minimax Pacman with Adversarial Ghosts, pacman will win with less socre because ghosts will not let him win easily.
# In the case of Minimax Pacman with Random Ghosts, pacman will win easily with high socre, because ghosts don't know how to obstruct pacman, they do action randomly.
# In the case of Expectimax Pacman with Adversarial Ghosts, pacman will lose most games because pacman only want to get higher score, he cares less of his safty, it may cause to his loss.
# In the case of Expectimax Pacman with Random Ghosts, pacman will win with the highest score, because pacman will set getting highest scores as his first goal, in the meanwhile ghosts are not smart enough to stop he.
#
# In the case of Minimax Pacman with Random Ghosts and Minimax Pacman with Adversarial Ghosts, it can implementing the correct assumption of the ghosts behaviors.

# %% [markdown]
# Q4

# %% [markdown]
# Because the two ghosts have nearly the same game goals under the minimax algorithm, they will behave consistently even without contact.
